# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Gelir dağılımı örneği (Sadece 'all races' kısmı)
# Burada excel verisini manuel olarak budadım. Sadece bu kısmını aldım.
df = pd.read_excel('dataf.xls')
df.head()
# Out:
#                 Range  People
# 0        Under $5,000    4218
# 1   $5,000 to  $9,999    3497
# 2  $10,000 to $14,999    5875
# 3  $15,000 to $19,999    6091
# 4  $20,000 to $24,999    6127

# %%
plt.figure(figsize=(10, 5))
plt.plot(df.Range, df.People)
plt.xlabel('Income Range, Under 5000 - Over 250000')
plt.ylabel('Number of people')
plt.show()

# %%
#IBM hisse senetleri verileri, getiri hesabı

df = pd.read_csv('ibmdata.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-12-31  160.410004  161.500000  160.380005  160.440002  135.486526
# 1  2015-01-02  161.309998  163.309998  161.000000  162.059998  136.854614
# 2  2015-01-05  161.270004  161.270004  159.190002  159.509995  134.701157
# 3  2015-01-06  159.669998  159.960007  155.169998  156.070007  131.796234
# 4  2015-01-07  157.199997  157.199997  154.029999  155.050003  130.934891
#
#     Volume
# 0  4011900
# 1  5525500
# 2  4880400
# 3  6146700
# 4  4701800

# %%
# Hisse değerlerindeki iki yıllık değişim
plt.plot(df.Open)

# %%
#the first open value in dataset
p_1 = df.Open[0]
#the last open value in dataset
p_2 = df.Open[504]

#income rate = (p2-p1)/p1
inc_rate = (p_2 - p_1)/p_1
print('Income rate: %', inc_rate*100)
# Out:
# Income rate: % 3.7591159214733127
