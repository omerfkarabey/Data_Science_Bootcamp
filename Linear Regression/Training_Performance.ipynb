# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from sklearn import linear_model
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('weatherHistory.csv')
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %% [markdown]
# ### Model 1 (etkileşimsiz)

# %%
temp = df['Temperature (C)'] - df['Apparent Temperature (C)']

# %%
X = df[['Humidity','Wind Speed (km/h)']]
Y = temp

X = sm.add_constant(X)

results = sm.OLS(Y,X).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.288
# Model:                            OLS   Adj. R-squared:                  0.288
# Method:                 Least Squares   F-statistic:                 1.949e+04
# Date:                Mon, 25 Mar 2019   Prob (F-statistic):               0.00
# Time:                        12:05:51   Log-Likelihood:            -1.7046e+05
# No. Observations:               96453   AIC:                         3.409e+05
# Df Residuals:                   96450   BIC:                         3.409e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Model 2 (nem ve rüzgar hızı etkileşimi dahil edildi)

# %%
hum_wind = df['Humidity'] * df['Wind Speed (km/h)']
df['hum_wind'] = hum_wind

X2 = df[['Humidity', 'Wind Speed (km/h)', 'hum_wind']]
Y2 = temp

X2 = sm.add_constant(X2)

results2 = sm.OLS(Y2,X2).fit()
results2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.341
# Model:                            OLS   Adj. R-squared:                  0.341
# Method:                 Least Squares   F-statistic:                 1.666e+04
# Date:                Mon, 25 Mar 2019   Prob (F-statistic):               0.00
# Time:                        12:06:59   Log-Likelihood:            -1.6669e+05
# No. Observations:               96453   AIC:                         3.334e+05
# Df Residuals:                   96449   BIC:                         3.334e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# * Her iki modelimizde de P istatistiklerimiz anlamlı.
# * İkinci modelimizde R-squared ve Adjusted R-squared değerlerinin arttığını görüyoruz. Modelimiz bir öncekine göre daha iyi bir model diyebiliriz.

# %% [markdown]
# ### Model 3 (Model 1'e görünürlük dahil edildi)

# %%
X3 = df[['Humidity','Wind Speed (km/h)', 'Visibility (km)']]
Y3 = temp

X3 = sm.add_constant(X3)

results3 = sm.OLS(Y,X3).fit()
results3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.304
# Model:                            OLS   Adj. R-squared:                  0.303
# Method:                 Least Squares   F-statistic:                 1.401e+04
# Date:                Mon, 25 Mar 2019   Prob (F-statistic):               0.00
# Time:                        12:14:31   Log-Likelihood:            -1.6938e+05
# No. Observations:               96453   AIC:                         3.388e+05
# Df Residuals:                   96449   BIC:                         3.388e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# * Model 1 ve Model 3'ü karşılaştırırsak, R-sq ev Adj.R-sq değerlerindeki artışı görürüz. Model 2 hedefimizi daha iyi açıklıyor.
# * Etkileşim terimi ve görünürlük açısından model 2 ve model 3'ü karşılaştırırsak, etkileşim teriminin adjusted R squared değerine katkısı daha fazla. Yani modelimizin varyansını açıklamada daha fazla yardımcı oluyor. Bu açıdan etkileşimli model daha iyi performans gösterir diyebiliriz.

# %% [markdown]
# AIC ve BIC değerleri açısından üç modeli incelersek, en iyi model ikincisi, yani etkileşimli modeldir. En zayıf model ise üçüncü, yani görünürlüğün dahil edildiği modeldir.
